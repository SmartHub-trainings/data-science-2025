# %%
class Quadratic:
    def __init__(self,a=1,b=0,c=0):
        self.a=a
        self.b=b
        self.c=c

# %%
q1= Quadratic(2,6,-3)
q2= Quadratic(b=6,c=7)

# %%
q1.a
# Out:
# 2

# %%
q1.c
# Out:
# -3

# %%
q2.a
# Out:
# 1

# %%
q2.b
# Out:
# 6

# %%
class Quadratic:
    def __init__(self,a=1,b=0,c=0):
        self.a=a
        self.b=b
        self.c=c
        
    def get_discriminant(self):
        return self.b**2-4*self.a*self.c

# %%
clayton= Quadratic(2,6,-3)
q2= Quadratic(b=6,c=7)

# %%
q1.a
# Out:
# 2

# %%
q1.get_discriminant()
# Out:
# 60

# %%
clayton.b
# Out:
# 6

# %%
class Quadratic:
    def __init__(self,a=1,b=0,c=0):
        self.a=a
        self.b=b
        self.c=c
        
    def get_discriminant(self):
        return self.b**2-4*self.a*self.c
    
    def get_nature_of_roots(self):
        dis = self.get_discriminant()
        if dis>0:
            return "Real and distinct"
        elif dis==0:
            return "Real and repeated"
        else:
            return "Imaginary or Complex"

# %%
clayton1= Quadratic(1,-5,6)
clayton2= Quadratic(1,-4,4)
clayton3= Quadratic(1,0,4)

# %%
clayton1.get_nature_of_roots()
# Out:
# 'Real and distinct'

# %%
clayton1.get_discriminant()
# Out:
# 1

# %%
clayton2.get_nature_of_roots()
# Out:
# 'Real and repeated'

# %%
clayton2.get_discriminant()
# Out:
# 0

# %%
clayton3.get_nature_of_roots()
# Out:
# 'Imaginary or Complex'

# %%
clayton3.get_discriminant()
# Out:
# -16

# %%
class Quadratic:
    degree =2
    def __init__(self,a=1,b=0,c=0):
        self.a=a # instance attribute
        self.b=b
        self.c=c
        
    def get_discriminant(self):
        return self.b**2-4*self.a*self.c
    
    def get_nature_of_roots(self):
        dis = self.get_discriminant()
        if dis>0:
            return "Real and distinct"
        elif dis==0:
            return "Real and repeated"
        else:
            return "Imaginary or Complex"

# %%
clayton1= Quadratic(1,-5,6)
clayton2= Quadratic(1,-4,4)
clayton3= Quadratic(1,0,4)

# %%
clayton1.b
# Out:
# -5

# %%
clayton2.b
# Out:
# -4

# %%
clayton1.degree
# Out:
# 2

# %%
clayton2.degree
# Out:
# 2

# %%
class Quadratic:
    degree =2
    def __init__(self,a=1,b=0,c=0):
        self.a=a # instance attribute
        self.b=b
        self.c=c
        
    def get_discriminant(self):
        return self.b**2-4*self.a*self.c
    
    def get_nature_of_roots(self):
        dis = self.get_discriminant()
        if dis>0:
            return "Real and distinct"
        elif dis==0:
            return "Real and repeated"
        else:
            return "Imaginary or Complex"
        
    def get_roots(self):
        dis = self.get_discriminant()
        if dis==0:
            x=-self.b/(2*self.a)
            return (x,x)
        elif dis>0:
            x1= (-self.b+(dis**0.5))/(2*self.a)
            x2= (-self.b-(dis**0.5))/(2*self.a)
            return x1,x2

# %%
clayton1= Quadratic(1,-5,6)
clayton2= Quadratic(1,-4,4)
clayton3= Quadratic(1,0,4)

# %%
clayton1.get_roots()
# Out:
# (3.0, 2.0)

# %%
clayton2.get_roots()
# Out:
# (2.0, 2.0)

# %%
class Quadratic:
    degree =2
    def __init__(self,a=1,b=0,c=0):
        self.a=a # instance attribute
        self.b=b
        self.c=c
        
    def get_discriminant(self):
        return self.b**2-4*self.a*self.c
    
    def get_nature_of_roots(self):
        dis = self.get_discriminant()
        if dis>0:
            return "Real and distinct"
        elif dis==0:
            return "Real and repeated"
        else:
            return "Imaginary or Complex"
        
    def get_roots(self):
        dis = self.get_discriminant()
        if dis==0:
            x=-self.b/(2*self.a)
            return (x,x)
        elif dis>0:
            x1= (-self.b+(dis**0.5))/(2*self.a)
            x2= (-self.b-(dis**0.5))/(2*self.a)
            return x1,x2
        else:
            x1= (-self.b+(dis**0.5))/(2*self.a)
            x2= (-self.b-(dis**0.5))/(2*self.a)
            return x1,x2

# %%
clayton1= Quadratic(1,-5,6)
clayton2= Quadratic(1,-4,4)
clayton3= Quadratic(1,0,4)

# %%
clayton3.get_roots()
# Out:
# ((1.2246467991473532e-16+2j), (-1.2246467991473532e-16-2j))

# %%
class Quadratic:
    degree =2
    def __init__(self,a=1,b=0,c=0):
        self.a=a # instance attribute
        self.b=b
        self.c=c
        
    def get_discriminant(self):
        return self.b**2-4*self.a*self.c
    
    def get_nature_of_roots(self):
        dis = self.get_discriminant()
        if dis>0:
            return "Real and distinct"
        elif dis==0:
            return "Real and repeated"
        else:
            return "Imaginary or Complex"
        
    def get_roots(self):
        dis = self.get_discriminant()
        if dis==0:
            x=-self.b/(2*self.a)
            return (x,x)
        else:
            x1= (-self.b+(dis**0.5))/(2*self.a)
            x2= (-self.b-(dis**0.5))/(2*self.a)
            return x1,x2

# %%
class Quadratic:
    degree =2
    def __init__(self,a=1,b=0,c=0):
        self.a=a # instance attribute
        self.b=b
        self.c=c
        
    def get_discriminant(self):
        return self.b**2-4*self.a*self.c
    
    def get_nature_of_roots(self):
        dis = self.get_discriminant()
        if dis>0:
            return "Real and distinct"
        elif dis==0:
            return "Real and repeated"
        else:
            return "Imaginary or Complex"
        
    def get_roots(self):
        dis = self.get_discriminant()
        x1= (-self.b+(dis**0.5))/(2*self.a)
        x2= (-self.b-(dis**0.5))/(2*self.a)
        return {
            "x1":x1,
            "x2":x2
        }

# %%
clayton1= Quadratic(1,-5,6)
clayton2= Quadratic(1,-4,4)
clayton3= Quadratic(1,0,4)

# %%
clayton1.get_roots()
# Out:
# {'x1': 3.0, 'x2': 2.0}

# %%
clayton2.get_roots()
# Out:
# {'x1': 2.0, 'x2': 2.0}

# %%
clayton3.get_roots()
# Out:
# {'x1': (1.2246467991473532e-16+2j), 'x2': (-1.2246467991473532e-16-2j)}
