# %%
def is_even(number):
    if number % 2 == 0:
        return True
    else:
        return False

# %%
is_even(5)
# Out:
# False

# %%
is_even(10)
# Out:
# True

# %%
def is_even(number):
    if number % 2 == 0:
        return True
    return False

# %%
def is_even(number):
    return number % 2 == 0:

# %%
def is_even(number):return number % 2 == 0:

# %%
double=lambda x: 2*x

# %%
double(3)
# Out:
# 6

# %%
double(345)
# Out:
# 690

# %%
is_odd =lambda number: number%2 !=0

# %%
is_odd(3)
# Out:
# True

# %%
is_odd(40)
# Out:
# False

# %%
is_odd =lambda number: bool(number%2)

# %%
is_odd(23)
# Out:
# True

# %%
is_odd(60)
# Out:
# False

# %%
def celsius_to_fahrenheit (c):return (c * 9/5)+32

# %%
celsius_to_fahrenheit=lambda  c:(c * 9/5)+32

# %%
celsius_to_fahrenheit(70)
# Out:
# 158.0

# %%
celsius_to_fahrenheit(40)
# Out:
# 104.0

# %%
celsius_to_fahrenheit(-40)
# Out:
# -40.0

# %%
def calculate_discount (price, discount_percentage=10):
    discount_price =price- price*(discount_percentage*1/100)
    return discount_price

# %%
def calculate_discount (price, discount_percentage=10):
    discount_price =price- price*(discount_percentage*1/100)
    return discount_price

# %%
def calculate_discount (price, discount_percentage=10):
    pay_percentage= (100-discount_percentage)/100
    discount_price =price*pay_percentage
    return discount_price

# %%
def calculate_discount (price, discount_percentage=10):
    return price*(100-discount_percentage)/100

# %%
dis=lambda price,discount_per=10:price*(100-discount_per)/100

# %%
dis(10000)
# Out:
# 9000.0

# %%
dis(10000,20)
# Out:
# 8000.0

# %%
def create_email(first_name, last_name, domain_name = "gmail.com"):
    print(f"{first_name}.{last_name}@{domain_name}")

# %%
create_email("smith","george")
# Out:
# smith.george@gmail.com

# %%
a=[1,3,5]
b=[4,5,6]
# result =[5,8,11]

# %%
result =[]
for i in range(3):
    result.append(a[i]+b[i])
print(result)
# Out:
# [5, 8, 11]

# %%
a=[1,3,5,5]
b=[4,5,6,4]
result =[]
for i in range(len(b)):
    result.append(a[i]+b[i])
print(result)
# Out:
# [5, 8, 11, 9]

# %%
a=[1,3,5,5,8]
b=[4,5,6,4]
result =[]
for i in range(len(a)):
    result.append(a[i]+b[i])
print(result)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_87864/1243134371.py in <module>
#       3 result =[]
#       4 for i in range(len(a)):
# ----> 5     result.append(a[i]+b[i])
#       6 print(result)
#       7
#
# IndexError: list index out of range

# %%
a=[1,3,5,5,8,23,45,67,46,77,76,77]
b=[4,5,6,4,53,5684,0]
if len(a)>len(b):
    length=len(b)
else:
    length=len(a)
result =[]
for i in range(length):
    result.append(a[i]+b[i])
print(result)
# Out:
# [5, 8, 11, 9, 61, 5707, 45]

# %%
a=[1,3,5,5,8,23,45,67,46,77,76,77]
b=[4,5,6,4,53,5684,0]
if len(a)>len(b):
    length=len(b)
else:
    length=len(a)
result =[]
for i in range(length):
    result.append(a[i]+b[i])
print(result)

# %%
a=[1,3,5,5,8,23,45,67,46,77,76,77]
b=[4,5,6,4,53,5684,0]
length=len(b) if len(a)>len(b) else len(a)
result =[]
for i in range(length):
    result.append(a[i]+b[i])
print(result)
