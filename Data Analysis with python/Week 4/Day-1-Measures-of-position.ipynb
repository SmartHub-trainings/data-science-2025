# %%
def get_quantile(data,k,kind="Q"):
    n=len(data)
    if kind =="Q":
        divisor=4
    elif kind=="D":
        divisor=10
    else:
        divisor=100
    position = (k/divisor)*(n+1)
    print(position)
    ceiled_position=
    print(type(position))

# %%
get_quantile([3,5,4,3,9,25,12],2,kind="D")
# Out:
# 1.6
# <class 'float'>

# %%
from math import floor,ceil

# %%
floor(1.2)
# Out:
# 1

# %%
floor(1.6)
# Out:
# 1

# %%
floor(1)
# Out:
# 1

# %%
ceil(1.2)
# Out:
# 2

# %%
ceil(3.5)
# Out:
# 4

# %%
ceil(4.0)
# Out:
# 4

# %%
def get_quantile(data,k,kind="Q"):
    n=len(data)
    if kind =="Q":
        divisor=4
    elif kind=="D":
        divisor=10
    else:
        divisor=100
    position = (k/divisor)*(n+1)
    print(position)
    ceiled_position=ceil(position)
    are_equal=position==ceiled_position
    print(are_equal)
    print(ceiled_position)

# %%
get_quantile([3,5,4,3,9,25,12],2,kind="Q")
# Out:
# 4.0
# True
# 4

# %%
def get_quantile(data,k,kind="Q"):
    n=len(data)
    if kind =="Q":
        divisor=4
    elif kind=="D":
        divisor=10
    else:
        divisor=100
    position = (k/divisor)*(n+1)
    print(position)
    ceiled_position=ceil(position)
    are_equal=position==ceiled_position
    print(are_equal)
    print(ceiled_position)
    data.sort()
    print(data)
    if are_equal:
        result =data[int(position)-1]
    else:
        pre_position = ceiled_position-1
        post_position=ceiled_position
        result=(data[pre_position-1]+data[post_position-1])/2
   
    return result

# %%
get_quantile([3,5,4,3,9,25,12],2,kind="P")
# Out:
# 0.16
# False
# 1
# [3, 3, 4, 5, 9, 12, 25]
# 14.0

# %%
def get_quantile(data,k,kind="Q"):
    n=len(data)
    if kind =="Q":
        divisor=4
    elif kind=="D":
        divisor=10
    else:
        divisor=100
    position = (k/divisor)*(n+1)
    print(position)
    ceiled_position=ceil(position)
    are_equal=position==ceiled_position
    print(are_equal)
    print(ceiled_position)
    data.sort()
    print(data)
    if position<1:
        result =data[0]
    elif are_equal:
        result =data[int(position)-1]
    else:
        pre_position = ceiled_position-1
        post_position=ceiled_position
        result=(data[pre_position-1]+data[post_position-1])/2
   
    return result

# %%
get_quantile([3,5,4,3,9,25,12],2,kind="P")
# Out:
# 0.16
# False
# 1
# [3, 3, 4, 5, 9, 12, 25]
# 3
