# %%
import numpy as np

# %%
A=np.random.randint(20,50,(2,3))

# %%
B=np.random.randint(20,50,(2,3))

# %%
A
# Out:
# array([[42, 37, 23],
#        [39, 42, 32]])

# %%
B
# Out:
# array([[22, 21, 34],
#        [45, 44, 39]])

# %%
A+B
# Out:
# array([[64, 58, 57],
#        [84, 86, 71]])

# %%
A-B
# Out:
# array([[ 20,  16, -11],
#        [ -6,  -2,  -7]])

# %%
A/B
# Out:
# array([[1.90909091, 1.76190476, 0.67647059],
#        [0.86666667, 0.95454545, 0.82051282]])

# %%
A
# Out:
# array([[42, 37, 23],
#        [39, 42, 32]])

# %%
A+7
# Out:
# array([[49, 44, 30],
#        [46, 49, 39]])

# %%
C=np.array([2,1,5])

# %%
D=np.array([2,4,5,6])

# %%
C+D
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_60857/3148850031.py in <module>
# ----> 1 C+D
#
# ValueError: operands could not be broadcast together with shapes (3,) (4,)

# %%
A+D
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_60857/2790886302.py in <module>
# ----> 1 A+D
#
# ValueError: operands could not be broadcast together with shapes (2,3) (4,)

# %%
A+C
# Out:
# array([[44, 38, 28],
#        [41, 43, 37]])

# %%
A
# Out:
# array([[42, 37, 23],
#        [39, 42, 32]])

# %%
C
# Out:
# array([2, 1, 5])

# %%
D
# Out:
# array([2, 4, 5, 6])

# %%
B
# Out:
# array([[22, 21, 34],
#        [45, 44, 39]])

# %%
D
# Out:
# array([2, 4, 5, 6])

# %%
E=np.array([4]) #:[4,4,4,4]

# %%
D+E
# Out:
# array([ 6,  8,  9, 10])

# %%
F=np.array([2,4])

# %%
D+F
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_60857/3901161755.py in <module>
# ----> 1 D+F
#
# ValueError: operands could not be broadcast together with shapes (4,) (2,)

# %%
A
# Out:
# array([[42, 37, 23],
#        [39, 42, 32]])

# %%
H=np.array([[3],[6]])

# %%
A
# Out:
# array([[42, 37, 23],
#        [39, 42, 32]])

# %%
H
# Out:
# array([[3],
#        [6]])

# %%
A+H
# Out:
# array([[45, 40, 26],
#        [45, 48, 38]])

# %% [markdown]
# ## Realtional and logical operations

# %%
D
# Out:
# array([2, 4, 5, 6])

# %%
D>3
# Out:
# array([False,  True,  True,  True])

# %%
A
# Out:
# array([[42, 37, 23],
#        [39, 42, 32]])

# %%
A<42
# Out:
# array([[False,  True,  True],
#        [ True, False,  True]])

# %%
A>30 and A<42
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_60857/446183601.py in <module>
# ----> 1 A>30 and A<42
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
A>30 & A<42
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_60857/1342608631.py in <module>
# ----> 1 A>30 & A<42
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
(A>30) & (A<42)
# Out:
# array([[False,  True, False],
#        [ True, False,  True]])

# %%
A>30
# Out:
# array([[ True,  True, False],
#        [ True,  True,  True]])

# %%
A<42
# Out:
# array([[False,  True,  True],
#        [ True, False,  True]])

# %%
(A>30) or (A<42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_60857/2534745258.py in <module>
# ----> 1 (A>30) or (A<42)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
(A>30) | (A<42)
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True]])

# %%
A>30
# Out:
# array([[ True,  True, False],
#        [ True,  True,  True]])

# %%
~(A>30)
# Out:
# array([[False, False,  True],
#        [False, False, False]])

# %% [markdown]
# ## Indexing and Slicing

# %%
x=[3,4,6,8,5,7]

# %%
x[1]
# Out:
# 4

# %%
y=[[3,5],[5,6],[5,3,6]]

# %%
y[0]
# Out:
# [3, 5]

# %%
y[-1]
# Out:
# [5, 3, 6]

# %%
y[2]
# Out:
# [5, 3, 6]

# %%
y[1]
# Out:
# [5, 6]

# %%
y[1][1]
# Out:
# 6

# %%
y[2][1]
# Out:
# 3

# %%
y[2,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_60857/4189771167.py in <module>
# ----> 1 y[2,1]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
z=np.array([[3,5],[5,6],[3,6]])

# %%
z
# Out:
# array([[3, 5],
#        [5, 6],
#        [3, 6]])

# %%
z[1][1]
# Out:
# 6

# %%
z[1,1]
# Out:
# 6

# %%
z[-1,0]
# Out:
# 3

# %%
z[-1][0]
# Out:
# 3

# %%
x
# Out:
# [3, 4, 6, 8, 5, 7]

# %%
x[0:3] # x[0:3:1]
# Out:
# [3, 4, 6]

# %%
x[0:5:2]#= x[:5:2]
# Out:
# [3, 6, 5]

# %%
x[::-1]
# Out:
# [7, 5, 8, 6, 4, 3]

# %%
x[::-2]
# Out:
# [7, 8, 4]

# %%
x[::2]
# Out:
# [3, 6, 5]

# %%
z
# Out:
# array([[3, 5],
#        [5, 6],
#        [3, 6]])

# %%
z_1=z.ravel()

# %%
z_1
# Out:
# array([3, 5, 5, 6, 3, 6])

# %%
z_1[:6:3]
# Out:
# array([3, 6])

# %%
z
# Out:
# array([[3, 5],
#        [5, 6],
#        [3, 6]])

# %%
z[:,0]
# Out:
# array([3, 5, 3])

# %%
z[:,-1]
# Out:
# array([5, 6, 6])

# %%
z[1:3,:]
# Out:
# array([[5, 6],
#        [3, 6]])

# %%
z[::2]
# Out:
# array([[3, 5],
#        [3, 6]])
