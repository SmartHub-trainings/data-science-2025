# %%
import numpy as np

# %%
x= np.random.randint(0,100,20)
y=np.random.randint(0,200,20)

# %%
x
# Out:
# array([23, 74, 15, 46, 85, 63, 80, 33, 29, 11, 19, 65, 23, 15, 12, 10, 56,
#        69, 27, 48])

# %%
y
# Out:
# array([ 58,  94, 145,  27,  46, 113, 182, 192, 101,  84, 158,  26, 117,
#         23,  90, 170, 130, 118,  72,  71])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.08895721],
#        [-0.08895721,  1.        ]])

# %%
z= -3*x+4+np.random.normal(size=20)*50

# %%
plt.scatter(x,z)

# %%
np.corrcoef(x,z)
# Out:
# array([[ 1.        , -0.78663125],
#        [-0.78663125,  1.        ]])

# %%
np.random.normal(size=20)*50
# Out:
# array([ -95.2668116 ,  -47.78581014,  -18.707082  ,   68.62878985,
#         -55.51773704,   55.14644999,   35.69615181, -129.36609099,
#         -26.06516769,   15.9519964 ,    1.1991822 ,   58.24738232,
#          68.79587636,    5.51336674,   15.09935333,   85.52063454,
#          13.85269848,   -4.12363617,  -26.70768707,  -54.92583935])

# %%
x
# Out:
# array([23, 74, 15, 46, 85, 63, 80, 33, 29, 11, 19, 65, 23, 15, 12, 10, 56,
#        69, 27, 48])

# %%
x
# Out:
# array([23, 74, 15, 46, 85, 63, 80, 33, 29, 11, 19, 65, 23, 15, 12, 10, 56,
#        69, 27, 48])

# %%
y=z

# %%
y
# Out:
# array([ -62.42054648, -145.78481101,  -87.65891289,  -80.92885469,
#        -290.12116439, -175.53300137, -203.77381413, -135.65490056,
#         -80.72041381,   11.62446349,  -61.32450691, -140.12085003,
#         -11.13114191,  -36.30115347,   -4.60057764, -156.83588161,
#        -186.34652706, -150.96244624, -138.56986063, -141.10291543])

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.78663125],
#        [-0.78663125,  1.        ]])

# %%
sum_x=x.sum()

# %%
sum_y =y.sum()

# %%
sum_xy=(x*y).sum()

# %%
sum_xy
# Out:
# -120035.03808470868

# %%
sum_x_sq= (x**2).sum()
sum_y_sq =(y**2).sum()

# %%
n= len(x)

# %%
n
# Out:
# 20

# %%
numerator= n*sum_xy-sum_x*sum_y

# %%
denomiator= ((n*sum_x_sq-sum_x**2)*(n*sum_y_sq-sum_y**2))**0.5

# %%
numerator/denomiator
# Out:
# -0.7866312548295036
