# %%
import numpy as np

# %%
x= np.random.randint(0,100,20)

# %%
x
# Out:
# array([27, 56, 37, 20, 20, 32, 16, 45, 67, 68, 83, 83, 12, 23, 58, 17, 78,
#        73, 78, 52])

# %%
x.sort()

# %%
x
# Out:
# array([12, 16, 17, 20, 20, 23, 27, 32, 37, 45, 52, 56, 58, 67, 68, 73, 78,
#        78, 83, 83])

# %%
x.max()
# Out:
# 83

# %%
x.min()
# Out:
# 12

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(x)
plt.grid()

# %%
np.percentile(x,25)
# Out:
# 22.25

# %%
np.percentile(x,50)
# Out:
# 48.5

# %%
x
# Out:
# array([12, 16, 17, 20, 20, 23, 27, 32, 37, 45, 52, 56, 58, 67, 68, 73, 78,
#        78, 83, 83])

# %%
x[4]=300

# %%
x
# Out:
# array([ 12,  16,  17,  20, 300,  23,  27,  32,  37,  45,  52,  56,  58,
#         67,  68,  73,  78,  78,  83,  83])

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9e0131bc40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9e01310070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9e0131b040>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9e01312fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9e01312880>],
#  'means': []}

# %%
y=np.random.randint(-100,100,30)

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9e012c46d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9e012ca0d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9e012c4340>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9e012ca8e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9e012cad60>],
#  'means': []}

# %%
y
# Out:
# array([-31, -95,  84, -99,  21, -10, -51,  -3,  34, -46,  -8, -50, -82,
#        -95, -53,  31,  13,  86, -84, -51, -90, -14, -62, -68, -72,  51,
#         69,  38, -63, -70])

# %%
y.mean()
# Out:
# -25.666666666666668

# %%
y.std()
# Out:
# 55.50695652098232

# %%
z=np.random.randint(0,120,15)
