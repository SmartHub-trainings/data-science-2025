# %%
import pandas as pd

# %%
cars = pd.read_csv("../datasets/cars.csv")

# %%
cars.head()
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
#
#   Fuel Type Transmission   Location   Color   Owner Seller Type   Engine  \
# 0    Petrol       Manual       Pune    Grey   First   Corporate  1198 cc
# 1    Diesel       Manual   Ludhiana   White  Second  Individual  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon   First  Individual  1197 cc
# 3    Petrol       Manual  Mangalore     Red   First  Individual  1197 cc
# 4    Diesel       Manual     Mumbai    Grey   First  Individual  2393 cc
#
# ...

# %%
cars.tail()
# Out:
#           Make                                  Model    Price  Year  \
# 2054  Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055   Hyundai                           Eon D-Lite +   275000  2014
# 2056      Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057       BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058  Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# 2054      90300    Diesel       Manual       Surat   White   First
# 2055      83000    Petrol       Manual   Ahmedabad   White  Second
# 2056      73000    Petrol       Manual       Thane  Silver   First
# 2057      60474    Diesel    Automatic  Coimbatore   White   First
# 2058      72000    Diesel       Manual    Guwahati   White   First
#
#      Seller Type   Engine           Max Power         Max Torque Drivetrain  \
# ...

# %%
cars.Price
# Out:
# 0        505000
# 1        450000
# 2        220000
# 3        799000
# 4       1950000
#          ...
# 2054     850000
# 2055     275000
# 2056     240000
# 2057    4290000
# 2058     670000
# Name: Price, Length: 2059, dtype: int64

# %%
cars.Year
# Out:
# 0       2017
# 1       2014
# 2       2011
# 3       2019
# 4       2018
#         ...
# 2054    2016
# 2055    2014
# 2056    2013
# 2057    2018
# 2058    2017
# Name: Year, Length: 2059, dtype: int64

# %%
cars[["Price","Year"]]
# Out:
#         Price  Year
# 0      505000  2017
# 1      450000  2014
# 2      220000  2011
# 3      799000  2019
# 4     1950000  2018
# ...       ...   ...
# 2054   850000  2016
# 2055   275000  2014
# 2056   240000  2013
# 2057  4290000  2018
# 2058   670000  2017
#
# [2059 rows x 2 columns]

# %%
cars.Year>2018
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 2054    False
# 2055    False
# 2056    False
# 2057    False
# 2058    False
# Name: Year, Length: 2059, dtype: bool

# %%
(cars.Year>2018).sum()
# Out:
# 587

# %%
(~(cars.Year>2018)).sum()
# Out:
# 1472

# %%
cars.Year[cars.Year>2018]
# Out:
# 3       2019
# 12      2019
# 13      2019
# 16      2019
# 18      2020
#         ...
# 2022    2021
# 2030    2021
# 2032    2020
# 2044    2022
# 2051    2021
# Name: Year, Length: 587, dtype: int64

# %%
cars.Price[cars.Year>2018]
# Out:
# 3        799000
# 12      1075000
# 13      1695000
# 16       449000
# 18       699000
#          ...
# 2022    1975000
# 2030    1325000
# 2032    8900000
# 2044    2765000
# 2051     925000
# Name: Price, Length: 587, dtype: int64

# %%
cars[cars.Year>2018]
# Out:
#                Make                                    Model    Price  Year  \
# 3            Toyota                                 Glanza G   799000  2019
# 12    Maruti Suzuki     Ciaz Alpha Hybrid 1.5 AT [2018-2020]  1075000  2019
# 13             Tata                   Harrier XZ [2019-2020]  1695000  2019
# 16    Maruti Suzuki                         Alto 800 LXi (O)   449000  2019
# 18    Maruti Suzuki                      Wagon R ZXi 1.2 AMT   699000  2020
# ...             ...                                      ...      ...   ...
# 2022            Kia       Seltos GTX Plus AT 1.4 [2019-2020]  1975000  2021
# 2030            Kia       Sonet GTX Plus 1.0 iMT [2020-2021]  1325000  2021
# 2032     Land Rover       Range Rover Velar 2.0 S Petrol 250  8900000  2020
# 2044       Mahindra  XUV700 AX 7 Petrol AT Luxury Pack 7 STR  2765000  2022
# 2051  Maruti Suzuki                        Vitara Brezza VXi   925000  2021
#
# ...

# %%
cars[cars.Year>2018][["Model","Make"]]
# Out:
#                                         Model           Make
# 3                                    Glanza G         Toyota
# 12       Ciaz Alpha Hybrid 1.5 AT [2018-2020]  Maruti Suzuki
# 13                     Harrier XZ [2019-2020]           Tata
# 16                           Alto 800 LXi (O)  Maruti Suzuki
# 18                        Wagon R ZXi 1.2 AMT  Maruti Suzuki
# ...                                       ...            ...
# 2022       Seltos GTX Plus AT 1.4 [2019-2020]            Kia
# 2030       Sonet GTX Plus 1.0 iMT [2020-2021]            Kia
# 2032       Range Rover Velar 2.0 S Petrol 250     Land Rover
# 2044  XUV700 AX 7 Petrol AT Luxury Pack 7 STR       Mahindra
# 2051                        Vitara Brezza VXi  Maruti Suzuki
#
# [587 rows x 2 columns]

# %%
cars[cars.Price>10e6]
# Out:
#                Make                                Model     Price  Year  \
# 95          Porsche       Cayenne Coupe Platinum Edition  16200000  2022
# 160   Mercedes-Benz                S-Class Maybach S 500  11500000  2016
# 259      Land Rover      Range Rover Sport SE 2.0 Petrol  12500000  2022
# 442   Mercedes-Benz                S-Class Maybach S 560  18500000  2021
# 483         Ferrari                              488 GTB  35000000  2018
# 510     Lamborghini                     Huracan LP 610-4  24000000  2016
# 542   Mercedes-Benz                      GLS 400d 4MATIC  13000000  2021
# 582      Land Rover      Range Rover 3.0 V6 Diesel Vogue  22000000  2019
# 977     Rolls-Royce                            Ghost 6.5  18000000  2011
# 1154         Toyota                      Vellfire Hybrid  11500000  2022
# 1178            BMW                 X6 xDrive40i M Sport  10800000  2021
# 1246    Rolls-Royce             Ghost Extended Wheelbase  20000000  2011
# ...

# %%
(cars.Price>100e6) & (cars.Year>2021)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2054    False
# 2055    False
# 2056    False
# 2057    False
# 2058    False
# Length: 2059, dtype: bool

# %%
cars[(cars.Price>10e6) & (cars.Year>2021)]
# Out:
#             Make                            Model     Price  Year  Kilometer  \
# 95       Porsche   Cayenne Coupe Platinum Edition  16200000  2022       2766
# 259   Land Rover  Range Rover Sport SE 2.0 Petrol  12500000  2022      22010
# 1154      Toyota                  Vellfire Hybrid  11500000  2022       4000
#
#      Fuel Type Transmission Location  Color  Owner Seller Type   Engine  \
# 95      Petrol    Automatic   Mumbai   Blue  First  Individual  2995 cc
# 259     Petrol    Automatic   Mohali  White  First  Individual  1997 cc
# 1154    Hybrid    Automatic    Delhi  Black  First  Individual  2494 cc
#
#                Max Power         Max Torque Drivetrain  Length   Width  \
# 95    335 bhp @ 5300 rpm  450 Nm @ 1340 rpm        AWD  4931.0  1983.0
# 259   296 bhp @ 5500 rpm  400 Nm @ 1500 rpm        AWD  4879.0  2073.0
# 1154  115 bhp @ 4700 rpm  198 Nm @ 2800 rpm        AWD  4935.0  1850.0
#
#       Height  Seating Capacity  Fuel Tank Capacity
# ...

# %%
cars.query("Price>10e6 and Year>2021")
# Out:
#             Make                            Model     Price  Year  Kilometer  \
# 95       Porsche   Cayenne Coupe Platinum Edition  16200000  2022       2766
# 259   Land Rover  Range Rover Sport SE 2.0 Petrol  12500000  2022      22010
# 1154      Toyota                  Vellfire Hybrid  11500000  2022       4000
#
#      Fuel Type Transmission Location  Color  Owner Seller Type   Engine  \
# 95      Petrol    Automatic   Mumbai   Blue  First  Individual  2995 cc
# 259     Petrol    Automatic   Mohali  White  First  Individual  1997 cc
# 1154    Hybrid    Automatic    Delhi  Black  First  Individual  2494 cc
#
#                Max Power         Max Torque Drivetrain  Length   Width  \
# 95    335 bhp @ 5300 rpm  450 Nm @ 1340 rpm        AWD  4931.0  1983.0
# 259   296 bhp @ 5500 rpm  400 Nm @ 1500 rpm        AWD  4879.0  2073.0
# 1154  115 bhp @ 4700 rpm  198 Nm @ 2800 rpm        AWD  4935.0  1850.0
#
#       Height  Seating Capacity  Fuel Tank Capacity
# ...

# %%
cars.head()
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
#
#   Fuel Type Transmission   Location   Color   Owner Seller Type   Engine  \
# 0    Petrol       Manual       Pune    Grey   First   Corporate  1198 cc
# 1    Diesel       Manual   Ludhiana   White  Second  Individual  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon   First  Individual  1197 cc
# 3    Petrol       Manual  Mangalore     Red   First  Individual  1197 cc
# 4    Diesel       Manual     Mumbai    Grey   First  Individual  2393 cc
#
# ...

# %%
cars.Price
# Out:
# 0        505000
# 1        450000
# 2        220000
# 3        799000
# 4       1950000
#          ...
# 2054     850000
# 2055     275000
# 2056     240000
# 2057    4290000
# 2058     670000
# Name: Price, Length: 2059, dtype: int64

# %%
cars["Price"]
# Out:
# 0        505000
# 1        450000
# 2        220000
# 3        799000
# 4       1950000
#          ...
# 2054     850000
# 2055     275000
# 2056     240000
# 2057    4290000
# 2058     670000
# Name: Price, Length: 2059, dtype: int64

# %%
cars["Fuel Type"]
# Out:
# 0       Petrol
# 1       Diesel
# 2       Petrol
# 3       Petrol
# 4       Diesel
#          ...
# 2054    Diesel
# 2055    Petrol
# 2056    Petrol
# 2057    Diesel
# 2058    Diesel
# Name: Fuel Type, Length: 2059, dtype: object

# %%
cars.Price
# Out:
# 0        505000
# 1        450000
# 2        220000
# 3        799000
# 4       1950000
#          ...
# 2054     850000
# 2055     275000
# 2056     240000
# 2057    4290000
# 2058     670000
# Name: Price, Length: 2059, dtype: int64

# %%
cars.Price.sort_values()
# Out:
# 491        49000
# 487        71001
# 824       100000
# 459       114999
# 1037      120000
#           ...
# 1890    20000000
# 582     22000000
# 510     24000000
# 1305    27500000
# 483     35000000
# Name: Price, Length: 2059, dtype: int64

# %%
cars.Price.sort_values(ascending=False)
# Out:
# 483     35000000
# 1305    27500000
# 510     24000000
# 582     22000000
# 1369    20000000
#           ...
# 1037      120000
# 459       114999
# 824       100000
# 487        71001
# 491        49000
# Name: Price, Length: 2059, dtype: int64

# %%
cars.sort_values(["Price"])
# Out:
#                Make                                Model     Price  Year  \
# 491            Tata                            Nano Base     49000  2010
# 487   Maruti Suzuki                        Zen LXi BS-II     71001  2004
# 824           Honda                         City 1.5 EXi    100000  2002
# 459            Tata              Manza Aqua Safire BS-IV    114999  2012
# 1037  Maruti Suzuki                       Ritz Vdi BS-IV    120000  2009
# ...             ...                                  ...       ...   ...
# 1890  Mercedes-Benz                        S-Class S 450  20000000  2021
# 582      Land Rover      Range Rover 3.0 V6 Diesel Vogue  22000000  2019
# 510     Lamborghini                     Huracan LP 610-4  24000000  2016
# 1305     Land Rover  Range Rover 3.0 V6 Diesel Vogue LWB  27500000  2020
# 483         Ferrari                              488 GTB  35000000  2018
#
#       Kilometer Fuel Type Transmission   Location   Color      Owner  \
# ...

# %%
cars.sort_values(["Price"],ascending=False)
# Out:
#                Make                                Model     Price  Year  \
# 483         Ferrari                              488 GTB  35000000  2018
# 1305     Land Rover  Range Rover 3.0 V6 Diesel Vogue LWB  27500000  2020
# 510     Lamborghini                     Huracan LP 610-4  24000000  2016
# 582      Land Rover      Range Rover 3.0 V6 Diesel Vogue  22000000  2019
# 1369    Rolls-Royce             Ghost Extended Wheelbase  20000000  2012
# ...             ...                                  ...       ...   ...
# 1037  Maruti Suzuki                       Ritz Vdi BS-IV    120000  2009
# 459            Tata              Manza Aqua Safire BS-IV    114999  2012
# 824           Honda                         City 1.5 EXi    100000  2002
# 487   Maruti Suzuki                        Zen LXi BS-II     71001  2004
# 491            Tata                            Nano Base     49000  2010
#
#       Kilometer Fuel Type Transmission   Location   Color      Owner  \
# ...

# %%
cars.sort_values(["Price"],ascending=False).head(10)
# Out:
#                Make                                Model     Price  Year  \
# 483         Ferrari                              488 GTB  35000000  2018
# 1305     Land Rover  Range Rover 3.0 V6 Diesel Vogue LWB  27500000  2020
# 510     Lamborghini                     Huracan LP 610-4  24000000  2016
# 582      Land Rover      Range Rover 3.0 V6 Diesel Vogue  22000000  2019
# 1369    Rolls-Royce             Ghost Extended Wheelbase  20000000  2012
# 1246    Rolls-Royce             Ghost Extended Wheelbase  20000000  2011
# 1890  Mercedes-Benz                        S-Class S 450  20000000  2021
# 1313     Land Rover      Range Rover 3.0 V6 Diesel Vogue  19300000  2019
# 1912  Mercedes-Benz           S-Class S 350D [2018-2020]  18500000  2021
# 442   Mercedes-Benz                S-Class Maybach S 560  18500000  2021
#
#       Kilometer Fuel Type Transmission   Location  Color             Owner  \
# 483        9500    Petrol    Automatic      Delhi  Black             First
# ...

# %%
cars.head()
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
#
#   Fuel Type Transmission   Location   Color   Owner Seller Type   Engine  \
# 0    Petrol       Manual       Pune    Grey   First   Corporate  1198 cc
# 1    Diesel       Manual   Ludhiana   White  Second  Individual  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon   First  Individual  1197 cc
# 3    Petrol       Manual  Mangalore     Red   First  Individual  1197 cc
# 4    Diesel       Manual     Mumbai    Grey   First  Individual  2393 cc
#
# ...

# %%
cars[cars.Make=="Toyota"]
# Out:
#         Make                            Model    Price  Year  Kilometer  \
# 3     Toyota                         Glanza G   799000  2019      37500
# 4     Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
# 37    Toyota   Innova 2.4 G 8 STR [2016-2017]  1900000  2019      71000
# 41    Toyota       Corolla Altis VL AT Petrol  1095000  2016      45000
# 55    Toyota        Innova 2.5 GX BS IV 7 STR   865000  2015      43634
# ...      ...                              ...      ...   ...        ...
# 1992  Toyota              Innova 2.0 G1 BS-IV   555000  2010     261236
# 2021  Toyota  Fortuner 2.8 4x2 MT [2016-2020]  3250000  2018     173000
# 2026  Toyota                     Etios Liva G   315000  2011      38091
# 2029  Toyota                        Etios VXD   465000  2014      82000
# 2036  Toyota                  Fortuner 3.0 MT  1000000  2010     127000
#
#      Fuel Type Transmission   Location   Color  Owner Seller Type   Engine  \
# ...

# %%
cars.set_index(["Make"])
# Out:
#                                                Model    Price  Year  \
# Make
# Honda                            Amaze 1.2 VX i-VTEC   505000  2017
# Maruti Suzuki                        Swift DZire VDI   450000  2014
# Hyundai                         i10 Magna 1.2 Kappa2   220000  2011
# Toyota                                      Glanza G   799000  2019
# Toyota               Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...                                              ...      ...   ...
# Mahindra                       XUV500 W8 [2015-2017]   850000  2016
# Hyundai                                 Eon D-Lite +   275000  2014
# Ford                     Figo Duratec Petrol ZXI 1.2   240000  2013
# BMW            5-Series 520d Luxury Line [2017-2019]  4290000  2018
# Mahindra           Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#                Kilometer Fuel Type Transmission    Location   Color   Owner  \
# Make
# ...

# %%
cars1=cars.set_index(["Make"])

# %%
cars1.loc["Toyota"]
# Out:
#                                   Model    Price  Year  Kilometer Fuel Type  \
# Make
# Toyota                         Glanza G   799000  2019      37500    Petrol
# Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000    Diesel
# Toyota   Innova 2.4 G 8 STR [2016-2017]  1900000  2019      71000    Diesel
# Toyota       Corolla Altis VL AT Petrol  1095000  2016      45000    Petrol
# Toyota        Innova 2.5 GX BS IV 7 STR   865000  2015      43634    Diesel
# ...                                 ...      ...   ...        ...       ...
# Toyota              Innova 2.0 G1 BS-IV   555000  2010     261236    Petrol
# Toyota  Fortuner 2.8 4x2 MT [2016-2020]  3250000  2018     173000    Diesel
# Toyota                     Etios Liva G   315000  2011      38091    Petrol
# Toyota                        Etios VXD   465000  2014      82000    Diesel
# Toyota                  Fortuner 3.0 MT  1000000  2010     127000    Diesel
#
# ...

# %%
cars
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
cars.set_index(["Make"])
# Out:
#                                                Model    Price  Year  \
# Make
# Honda                            Amaze 1.2 VX i-VTEC   505000  2017
# Maruti Suzuki                        Swift DZire VDI   450000  2014
# Hyundai                         i10 Magna 1.2 Kappa2   220000  2011
# Toyota                                      Glanza G   799000  2019
# Toyota               Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...                                              ...      ...   ...
# Mahindra                       XUV500 W8 [2015-2017]   850000  2016
# Hyundai                                 Eon D-Lite +   275000  2014
# Ford                     Figo Duratec Petrol ZXI 1.2   240000  2013
# BMW            5-Series 520d Luxury Line [2017-2019]  4290000  2018
# Mahindra           Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#                Kilometer Fuel Type Transmission    Location   Color   Owner  \
# Make
# ...

# %%
cars.set_index(["Make","Model"])
# Out:
#                                                        Price  Year  Kilometer  \
# Make          Model
# Honda         Amaze 1.2 VX i-VTEC                     505000  2017      87150
# Maruti Suzuki Swift DZire VDI                         450000  2014      75000
# Hyundai       i10 Magna 1.2 Kappa2                    220000  2011      67000
# Toyota        Glanza G                                799000  2019      37500
#               Innova 2.4 VX 7 STR [2016-2020]        1950000  2018      69000
# ...                                                      ...   ...        ...
# Mahindra      XUV500 W8 [2015-2017]                   850000  2016      90300
# Hyundai       Eon D-Lite +                            275000  2014      83000
# Ford          Figo Duratec Petrol ZXI 1.2             240000  2013      73000
# BMW           5-Series 520d Luxury Line [2017-2019]  4290000  2018      60474
# Mahindra      Bolero Power Plus ZLX [2016-2019]       670000  2017      72000
#
# ...

# %%
cars.sort_values(["Make","Model"])#.set_index(["Make","Model"])
# Out:
#        Make                         Model    Price  Year  Kilometer Fuel Type  \
# 718    Audi             A3 35 TDI Premium  2600000  2017      64000    Diesel
# 734    Audi             A3 35 TDI Premium  1800000  2014      76529    Diesel
# 910    Audi             A3 35 TDI Premium  2950000  2020      11000    Diesel
# 950    Audi             A3 35 TDI Premium  2900000  2019      15529    Diesel
# 605    Audi   A3 35 TDI Premium + Sunroof  2900000  2019      15530    Diesel
# ...     ...                           ...      ...   ...        ...       ...
# 1923  Volvo              XC40 D4 R-Design  3950000  2018      52000    Diesel
# 1597  Volvo              XC40 T4 R-Design  4400000  2020      16519    Petrol
# 1775  Volvo              XC60 Inscription  1950000  2016      79000    Diesel
# 902   Volvo  XC60 Inscription [2017-2020]  5800000  2019       3500    Diesel
# 1778  Volvo           XC90 D5 Inscription  8500000  2021      32500    Diesel
#
# ...

# %%
sort_index=["Make","Model"]
cars.sort_values(sort_index).set_index(sort_index)
# Out:
#                                       Price  Year  Kilometer Fuel Type  \
# Make  Model
# Audi  A3 35 TDI Premium             2600000  2017      64000    Diesel
#       A3 35 TDI Premium             1800000  2014      76529    Diesel
#       A3 35 TDI Premium             2950000  2020      11000    Diesel
#       A3 35 TDI Premium             2900000  2019      15529    Diesel
#       A3 35 TDI Premium + Sunroof   2900000  2019      15530    Diesel
# ...                                     ...   ...        ...       ...
# Volvo XC40 D4 R-Design              3950000  2018      52000    Diesel
#       XC40 T4 R-Design              4400000  2020      16519    Petrol
#       XC60 Inscription              1950000  2016      79000    Diesel
#       XC60 Inscription [2017-2020]  5800000  2019       3500    Diesel
#       XC90 D5 Inscription           8500000  2021      32500    Diesel
#
#                                    Transmission   Location  Color  Owner  \
# Make  Model
# ...
