# %%
import pandas as pd

# %%
data1=pd.read_csv("cars.csv")

# %%
data1
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
data1=pd.read_csv("cars.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data1=pd.read_csv("cars.csv")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
data1=pd.read_csv("datasets/cars.csv")

# %%
data1
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
data1.head()
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
#
#   Fuel Type Transmission   Location   Color   Owner Seller Type   Engine  \
# 0    Petrol       Manual       Pune    Grey   First   Corporate  1198 cc
# 1    Diesel       Manual   Ludhiana   White  Second  Individual  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon   First  Individual  1197 cc
# 3    Petrol       Manual  Mangalore     Red   First  Individual  1197 cc
# 4    Diesel       Manual     Mumbai    Grey   First  Individual  2393 cc
#
# ...

# %%
data1.tail()
# Out:
#           Make                                  Model    Price  Year  \
# 2054  Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055   Hyundai                           Eon D-Lite +   275000  2014
# 2056      Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057       BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058  Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# 2054      90300    Diesel       Manual       Surat   White   First
# 2055      83000    Petrol       Manual   Ahmedabad   White  Second
# 2056      73000    Petrol       Manual       Thane  Silver   First
# 2057      60474    Diesel    Automatic  Coimbatore   White   First
# 2058      72000    Diesel       Manual    Guwahati   White   First
#
#      Seller Type   Engine           Max Power         Max Torque Drivetrain  \
# ...

# %%
data1.sample(10)
# Out:
#                Make                                      Model    Price  Year  \
# 1536     Volkswagen                      Polo Highline1.2L (P)   525000  2014
# 333         Renault                          Duster RXL Petrol   600000  2017
# 1447           Audi                     Q5 40 TDI Premium Plus  4475000  2020
# 395   Mercedes-Benz                         M-Class ML 350 CDI  2450000  2014
# 1936          Honda                                   City CVT   185000  2008
# 704           Honda                             Jazz VX Petrol   585000  2017
# 181          Toyota                        Fortuner 3.0 4x4 MT  1675000  2014
# 177   Maruti Suzuki                                Wagon R VXi   350000  2013
# 1406        Hyundai  Grand i10 Asta 1.2 Kappa VTVT [2013-2016]   409999  2014
# 351        Mahindra        Thar AX 4-STR Convertible Petrol MT  1700000  2021
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
data1.head(7)
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
# 5  Maruti Suzuki                         Ciaz ZXi   675000  2017      73315
# 6  Mercedes-Benz             CLA 200 Petrol Sport  1898999  2015      47000
#
#   Fuel Type Transmission   Location   Color   Owner Seller Type   Engine  \
# 0    Petrol       Manual       Pune    Grey   First   Corporate  1198 cc
# 1    Diesel       Manual   Ludhiana   White  Second  Individual  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon   First  Individual  1197 cc
# ...

# %%
data1.columns
# Out:
# Index(['Make', 'Model', 'Price', 'Year', 'Kilometer', 'Fuel Type',
#        'Transmission', 'Location', 'Color', 'Owner', 'Seller Type', 'Engine',
#        'Max Power', 'Max Torque', 'Drivetrain', 'Length', 'Width', 'Height',
#        'Seating Capacity', 'Fuel Tank Capacity'],
#       dtype='object')

# %%
data1.rename(columns={"Price":"Car_Price"})
# Out:
#                Make                                  Model  Car_Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC     505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI     450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2     220000  2011
# 3            Toyota                               Glanza G     799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]    1950000  2018
# ...             ...                                    ...        ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]     850000  2016
# 2055        Hyundai                           Eon D-Lite +     275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2     240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]    4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]     670000  2017
#
# ...

# %%
data1
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
data1.rename(index={0:"Esther",3:"Charles"})
# Out:
#                   Make                                  Model    Price  Year  \
# Esther           Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1        Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2              Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# Charles         Toyota                               Glanza G   799000  2019
# 4               Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...                ...                                    ...      ...   ...
# 2054          Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055           Hyundai                           Eon D-Lite +   275000  2014
# 2056              Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057               BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058          Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
# ...

# %%
data1.shape
# Out:
# (2059, 20)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                2059 non-null   object
#  1   Model               2059 non-null   object
#  2   Price               2059 non-null   int64
#  3   Year                2059 non-null   int64
#  4   Kilometer           2059 non-null   int64
#  5   Fuel Type           2059 non-null   object
#  6   Transmission        2059 non-null   object
#  7   Location            2059 non-null   object
#  8   Color               2059 non-null   object
#  9   Owner               2059 non-null   object
#  10  Seller Type         2059 non-null   object
#  11  Engine              1979 non-null   object
#  12  Max Power           1979 non-null   object
#  13  Max Torque          1979 non-null   object
#  14  Drivetrain          1923 non-null   object
# ...

# %%
data1.describe()
# Out:
#               Price         Year     Kilometer       Length        Width  \
# count  2.059000e+03  2059.000000  2.059000e+03  1995.000000  1995.000000
# mean   1.702992e+06  2016.425449  5.422471e+04  4280.860652  1767.991980
# std    2.419881e+06     3.363564  5.736172e+04   442.458507   135.265825
# min    4.900000e+04  1988.000000  0.000000e+00  3099.000000  1475.000000
# 25%    4.849990e+05  2014.000000  2.900000e+04  3985.000000  1695.000000
# 50%    8.250000e+05  2017.000000  5.000000e+04  4370.000000  1770.000000
# 75%    1.925000e+06  2019.000000  7.200000e+04  4629.000000  1831.500000
# max    3.500000e+07  2022.000000  2.000000e+06  5569.000000  2220.000000
#
#             Height  Seating Capacity  Fuel Tank Capacity
# count  1995.000000       1995.000000         1946.000000
# mean   1591.735338          5.306266           52.002210
# std     136.073956          0.822170           15.110198
# min    1165.000000          2.000000           15.000000
# ...

# %%
data1.describe(include=["object"])
# Out:
#                  Make               Model Fuel Type Transmission Location  \
# count            2059                2059      2059         2059     2059
# unique             33                1050         9            2       77
# top     Maruti Suzuki  X1 sDrive20d xLine    Diesel       Manual   Mumbai
# freq              440                  15      1049         1133      342
#
#         Color  Owner Seller Type   Engine          Max Power  \
# count    2059   2059        2059     1979               1979
# unique     17      6           3      108                335
# top     White  First  Individual  1197 cc  89 bhp @ 4000 rpm
# freq      802   1619        1997      231                 90
#
#                Max Torque Drivetrain
# count                1979       1923
# unique                290          3
# top     200 Nm @ 1750 rpm        FWD
# freq                   90       1330

# %%
data1.describe(include=["object","int","float"])
# Out:
#                  Make               Model         Price         Year  \
# count            2059                2059  2.059000e+03  2059.000000
# unique             33                1050           NaN          NaN
# top     Maruti Suzuki  X1 sDrive20d xLine           NaN          NaN
# freq              440                  15           NaN          NaN
# mean              NaN                 NaN  1.702992e+06  2016.425449
# std               NaN                 NaN  2.419881e+06     3.363564
# min               NaN                 NaN  4.900000e+04  1988.000000
# 25%               NaN                 NaN  4.849990e+05  2014.000000
# 50%               NaN                 NaN  8.250000e+05  2017.000000
# 75%               NaN                 NaN  1.925000e+06  2019.000000
# max               NaN                 NaN  3.500000e+07  2022.000000
#
#            Kilometer Fuel Type Transmission Location  Color  Owner  \
# count   2.059000e+03      2059         2059     2059   2059   2059
# ...

# %% [markdown]
# ## Indexing,slicing(Filtering)

# %%
data1["Make"]
# Out:
# 0               Honda
# 1       Maruti Suzuki
# 2             Hyundai
# 3              Toyota
# 4              Toyota
#             ...
# 2054         Mahindra
# 2055          Hyundai
# 2056             Ford
# 2057              BMW
# 2058         Mahindra
# Name: Make, Length: 2059, dtype: object

# %%
data1["Engine"]
# Out:
# 0       1198 cc
# 1       1248 cc
# 2       1197 cc
# 3       1197 cc
# 4       2393 cc
#          ...
# 2054    2179 cc
# 2055     814 cc
# 2056    1196 cc
# 2057    1995 cc
# 2058    1493 cc
# Name: Engine, Length: 2059, dtype: object

# %%
data1.Make
# Out:
# 0               Honda
# 1       Maruti Suzuki
# 2             Hyundai
# 3              Toyota
# 4              Toyota
#             ...
# 2054         Mahindra
# 2055          Hyundai
# 2056             Ford
# 2057              BMW
# 2058         Mahindra
# Name: Make, Length: 2059, dtype: object

# %%
data1.Location
# Out:
# 0             Pune
# 1         Ludhiana
# 2          Lucknow
# 3        Mangalore
# 4           Mumbai
#            ...
# 2054         Surat
# 2055     Ahmedabad
# 2056         Thane
# 2057    Coimbatore
# 2058      Guwahati
# Name: Location, Length: 2059, dtype: object

# %%
data1.Transmission
# Out:
# 0          Manual
# 1          Manual
# 2          Manual
# 3          Manual
# 4          Manual
#           ...
# 2054       Manual
# 2055       Manual
# 2056       Manual
# 2057    Automatic
# 2058       Manual
# Name: Transmission, Length: 2059, dtype: object

# %%
data1.Transmission.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data1.columns
# Out:
# Index(['Make', 'Model', 'Price', 'Year', 'Kilometer', 'Fuel Type',
#        'Transmission', 'Location', 'Color', 'Owner', 'Seller Type', 'Engine',
#        'Max Power', 'Max Torque', 'Drivetrain', 'Length', 'Width', 'Height',
#        'Seating Capacity', 'Fuel Tank Capacity'],
#       dtype='object')

# %%
data1["Fuel Type"].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric', 'CNG + CNG',
#        'Hybrid', 'Petrol + CNG', 'Petrol + LPG'], dtype=object)

# %%
data1["Fuel Type"].unique().size
# Out:
# 9

# %%
data1.loc[0]
# Out:
# Make                                Honda
# Model                 Amaze 1.2 VX i-VTEC
# Price                              505000
# Year                                 2017
# Kilometer                           87150
# Fuel Type                          Petrol
# Transmission                       Manual
# Location                             Pune
# Color                                Grey
# Owner                               First
# Seller Type                     Corporate
# Engine                            1198 cc
# Max Power               87 bhp @ 6000 rpm
# Max Torque              109 Nm @ 4500 rpm
# Drivetrain                            FWD
# Length                             3990.0
# Width                              1680.0
# Height                             1505.0
# Seating Capacity                      5.0
# Fuel Tank Capacity                   35.0
# Name: 0, dtype: object

# %%
data1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data1.head(2)
# Out:
#             Make                Model   Price  Year  Kilometer Fuel Type  \
# 0          Honda  Amaze 1.2 VX i-VTEC  505000  2017      87150    Petrol
# 1  Maruti Suzuki      Swift DZire VDI  450000  2014      75000    Diesel
#
#   Transmission  Location  Color   Owner Seller Type   Engine  \
# 0       Manual      Pune   Grey   First   Corporate  1198 cc
# 1       Manual  Ludhiana  White  Second  Individual  1248 cc
#
#            Max Power         Max Torque Drivetrain  Length   Width  Height  \
# 0  87 bhp @ 6000 rpm  109 Nm @ 4500 rpm        FWD  3990.0  1680.0  1505.0
# 1  74 bhp @ 4000 rpm  190 Nm @ 2000 rpm        FWD  3995.0  1695.0  1555.0
#
#    Seating Capacity  Fuel Tank Capacity
# 0               5.0                35.0
# 1               5.0                42.0

# %%
data1.loc[20]
# Out:
# Make                      Maruti Suzuki
# Model                  S-Presso VXi AMT
# Price                            470000
# Year                               2020
# Kilometer                          2169
# Fuel Type                        Petrol
# Transmission                  Automatic
# Location                         Mumbai
# Color                              Grey
# Owner                             First
# Seller Type                  Individual
# Engine                           998 cc
# Max Power             67 bhp @ 5500 rpm
# Max Torque             90 Nm @ 3500 rpm
# Drivetrain                          FWD
# Length                           3565.0
# Width                            1520.0
# Height                           1564.0
# Seating Capacity                    5.0
# Fuel Tank Capacity                 27.0
# Name: 20, dtype: object

# %%
data1.loc[20,"Price"]
# Out:
# 470000

# %%
data1.loc[[0,3,200],["Make","Price","Location","Fuel Type"]]
# Out:
#        Make    Price   Location Fuel Type
# 0     Honda   505000       Pune    Petrol
# 3    Toyota   799000  Mangalore    Petrol
# 200     BMW  2975000     Mohali    Diesel

# %%
data1
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
data1.Year==2017
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2054    False
# 2055    False
# 2056    False
# 2057    False
# 2058     True
# Name: Year, Length: 2059, dtype: bool

# %%
data1[data1.Year==2017]
# Out:
#                Make                                        Model    Price  \
# 0             Honda                          Amaze 1.2 VX i-VTEC   505000
# 5     Maruti Suzuki                                     Ciaz ZXi   675000
# 7               BMW                         X1 xDrive20d M Sport  2650000
# 8             Skoda         Octavia 1.8 TSI Style Plus AT [2017]  1390000
# 10          Hyundai                         Elite i20 Sportz 1.2   591000
# ...             ...                                          ...      ...
# 1998  Maruti Suzuki                            Ciaz Alpha 1.4 AT   725000
# 1999        Hyundai  Grand i10 Sportz 1.2 Kappa VTVT [2016-2017]   400000
# 2010           Audi                   A4 30 TFSI Technology Pack  3000000
# 2049  Mercedes-Benz                               GLS 400 4MATIC  5950000
# 2058       Mahindra            Bolero Power Plus ZLX [2016-2019]   670000
#
#       Year  Kilometer Fuel Type Transmission    Location  Color   Owner  \
# ...

# %%
data1
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
data1.Price>5000000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2054    False
# 2055    False
# 2056    False
# 2057    False
# 2058    False
# Name: Price, Length: 2059, dtype: bool

# %%
data1[data1.Price>5000000]
# Out:
#                Make                                  Model     Price  Year  \
# 95          Porsche         Cayenne Coupe Platinum Edition  16200000  2022
# 96    Mercedes-Benz                C-Class Cabriolet C 300   5100000  2017
# 139            Audi                Q5 45 TFSI Premium Plus   5651000  2022
# 156      Land Rover                      Discovery Sport S   6500000  2020
# 160   Mercedes-Benz                  S-Class Maybach S 500  11500000  2016
# ...             ...                                    ...       ...   ...
# 1979            BMW                  X5 xDrive 30d M Sport   5500000  2017
# 2007  Mercedes-Benz   E-Class E 220d Exclusive [2019-2019]   6100000  2020
# 2012            BMW  X3 xDrive 20d Luxury Line [2018-2020]   6200000  2021
# 2032     Land Rover     Range Rover Velar 2.0 S Petrol 250   8900000  2020
# 2049  Mercedes-Benz                         GLS 400 4MATIC   5950000  2017
#
# ...

# %%
data1.Price<6000000
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2054    True
# 2055    True
# 2056    True
# 2057    True
# 2058    True
# Name: Price, Length: 2059, dtype: bool

# %%
data1[data1.Price<6000000]
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
(data1.Price>5000000) & (data1.Price<6000000)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2054    False
# 2055    False
# 2056    False
# 2057    False
# 2058    False
# Name: Price, Length: 2059, dtype: bool

# %%
data1[(data1.Price>6000000) & (data1.Price<7000000)]
# Out:
#                Make                                    Model    Price  Year  \
# 156      Land Rover                        Discovery Sport S  6500000  2020
# 371   Mercedes-Benz                  C-Class Cabriolet C 300  6500000  2020
# 479   Mercedes-Benz              GLC 220d 4MATIC Progressive  6400000  2022
# 525             BMW                   7-Series 730Ld M Sport  6900000  2017
# 595   Mercedes-Benz      E-Class E 200 Exclusive [2019-2019]  6500000  2021
# 611   Mercedes-Benz                      GLC 200 Progressive  6975000  2022
# 726   Mercedes-Benz    E-Class E 350 d Exclusive [2017-2019]  6225000  2019
# 789   Mercedes-Benz  GLC 220d 4MATIC Progressive [2019-2021]  6800000  2020
# 811   Mercedes-Benz               E-Class E 220 d Avantgarde  6500000  2019
# 837         Porsche                      Panamera 3.0 Diesel  6350000  2016
# 840   Mercedes-Benz                                GLS 350 d  6875000  2019
# ...

# %%
data1[(data1.Price>6000000) & (data1.Price<7000000)].shape
# Out:
# (28, 20)

# %%
data1[(data1.Price>6000000) & (data1.Price<7000000)].Make.unique()
# Out:
# array(['Land Rover', 'Mercedes-Benz', 'BMW', 'Porsche', 'Audi', 'Jeep'],
#       dtype=object)
