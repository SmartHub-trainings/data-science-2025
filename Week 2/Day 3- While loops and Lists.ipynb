# %%
for i in range(5):
    name= input("Enter a name: ")
    print(f"Your name is {name}")
# Out:
# Enter a name: Smith
# Your name is Smith
# Enter a name: Esthe
# Your name is Esthe
# Enter a name: Esther
# Your name is Esther
# Enter a name: Clinton
# Your name is Clinton
# Enter a name: Chemchris
# Your name is Chemchris

# %%
# while cond:
#     do_somthing

# %%
while count<6:
    name = input("Enter a name:")
    print(f"Your name is {name}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_49596/1880508181.py in <module>
# ----> 1 while count<6:
#       2     name = input("Enter a name:")
#       3     print(f"Your name is {name}")
#
# NameError: name 'count' is not defined

# %%
count=1
while count<6:
    name = input("Enter a name:")
    print(f"Your name is {name}")
# Out:
# Enter a name:Danny
# Your name is Danny
# Enter a name:Smith
# Your name is Smith
# Enter a name:Okon
# Your name is Okon
# Enter a name:Edison
# Your name is Edison
# Enter a name:Clinton
# Your name is Clinton
# Enter a name:George
# Your name is George
# Enter a name:gjjjd
# Your name is gjjjd
# Enter a name:bcjdjknkds
# Your name is bcjdjknkds
# Enter a name: cvmdbjhd
# Your name is  cvmdbjhd
# Enter a name:dscvdjshcbvhjds
# Your name is dscvdjshcbvhjds
# Enter a name:dcmdnbcjdbcjhds
# Your name is dcmdnbcjdbcjhds
# Enter a name:dscbdhcbdhde
# Your name is dscbdhcbdhde
# Enter a name:duhiuhvf
# Your name is duhiuhvf
# Enter a name:fvmbfdjhvf
# Your name is fvmbfdjhvf

# %%
count=1
while count<6:
    name = input("Enter a name:")
    print(f"Your name is {name}")
    count = count +1
# Out:
# Enter a name:g
# Your name is g
# Enter a name:y
# Your name is y
# Enter a name:ccbhbhjd
# Your name is ccbhbhjd
# Enter a name:dcbhd
# Your name is dcbhd
# Enter a name: bnbhcd
# Your name is  bnbhcd

# %%
while number >=0:
    number = float(input("Enter a number: "))
    print(number)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_61323/1547009171.py in <module>
# ----> 1 while number >=0:
#       2     number = float(input("Enter a number: "))
#       3     print(number)
#
# NameError: name 'number' is not defined

# %%
number = 2
while number >=0:
    number = float(input("Enter a number: "))
    print(number)
# Out:
# Enter a number: 89
# 89.0
# Enter a number: 23
# 23.0
# Enter a number: 78
# 78.0
# Enter a number: 0
# 0.0
# Enter a number: -6
# -6.0

# %%
number = float(input("Enter a number: "))
while number >=0:
    print(number)
    number = float(input("Enter a number: "))
# Out:
# Enter a number: 20
# 20.0
# Enter a number: 30
# 30.0
# Enter a number: 67
# 67.0
# Enter a number: 90
# 90.0
# Enter a number: 0
# 0.0
# Enter a number: 0.4
# 0.4
# Enter a number: 12
# 12.0
# Enter a number: -3

# %%
number = float(input("Enter a number: "))
while number >=0:
    number = float(input("Enter a number: "))
    print(number)

# %% [markdown]
# ## Break and continue statment

# %%
for char in "smith":
    print(char)
# Out:
# s
# m
# i
# t
# h

# %%
for char in "smith":
    if char =="i":
        continue
    print(char)
# Out:
# s
# m
# t
# h

# %%
for char in "smith":
    if char =="i":
        break
    print(char)
# Out:
# s
# m

# %% [markdown]
# ## Container

# %%
names =["ChemChris","Smith","Okon","Charles","Clayton"]

# %%
type(names)
# Out:
# list

# %%
numbers =[1,3,4,6,78,7]

# %%
numbers
# Out:
# [1, 3, 4, 6, 78, 7]

# %%
names
# Out:
# ['ChemChris', 'Smith', 'Okon', 'Charles', 'Clayton']

# %%
names[0]
# Out:
# 'ChemChris'

# %%
names[2]
# Out:
# 'Okon'

# %%
names[4]
# Out:
# 'Clayton'

# %%
names[-1]
# Out:
# 'Clayton'

# %%
names[-2]
# Out:
# 'Charles'

# %%
names
# Out:
# ['ChemChris', 'Smith', 'Okon', 'Charles', 'Clayton']

# %%
len(names)
# Out:
# 5

# %%
names[0:3]
# Out:
# ['ChemChris', 'Smith', 'Okon']

# %%
names[:3]
# Out:
# ['ChemChris', 'Smith', 'Okon']

# %%
names[1:3]
# Out:
# ['Smith', 'Okon']

# %%
names
# Out:
# ['ChemChris', 'Smith', 'Okon', 'Charles', 'Clayton']

# %%
names[:4][-2]
# Out:
# 'Okon'

# %%
names[:2][-2]
# Out:
# 'ChemChris'

# %%
names
# Out:
# ['ChemChris', 'Smith', 'Okon', 'Charles', 'Clayton']

# %%
numbers
# Out:
# [1, 3, 4, 6, 78, 7]

# %%
numbers
# Out:
# [1, 3, 4, 6, 78, 7]

# %%
["na",45,9.6]
# Out:
# ['na', 45, 9.6]

# %%
names
# Out:
# ['ChemChris', 'Smith', 'Okon', 'Charles', 'Clayton']

# %%
names.append("Edison")

# %%
names
# Out:
# ['ChemChris', 'Smith', 'Okon', 'Charles', 'Clayton', 'Edison']

# %%
names.append("German")

# %%
names
# Out:
# ['ChemChris', 'Smith', 'Okon', 'Charles', 'Clayton', 'Edison', 'German']

# %%
names.append(1233)

# %%
names
# Out:
# ['ChemChris', 'Smith', 'Okon', 'Charles', 'Clayton', 'Edison', 'German', 1233]

# %%
names.pop()
# Out:
# 1233

# %%
names
# Out:
# ['ChemChris', 'Smith', 'Okon', 'Charles', 'Clayton', 'Edison', 'German']

# %%
names.pop()
# Out:
# 'German'

# %%
names
# Out:
# ['ChemChris', 'Smith', 'Okon', 'Charles', 'Clayton', 'Edison']

# %%
names.pop(1)
# Out:
# 'Smith'

# %%
names
# Out:
# ['ChemChris', 'Okon', 'Charles', 'Clayton', 'Edison']

# %%
names.remove("Charles")

# %%
names
# Out:
# ['ChemChris', 'Okon', 'Clayton', 'Edison']

# %%
names.insert(0,"Diamond")

# %%
names
# Out:
# ['Diamond', 'ChemChris', 'Okon', 'Clayton', 'Edison']

# %%
# names.remove("ChemChris")
names.remove("Okon")
names.remove("Edison")

# %%
names
# Out:
# ['Diamond', 'Clayton']
