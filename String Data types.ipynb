# %%
number_of_red=2
number_of_blue=5
number_of_black=7
total_number_of_balls=number_of_black+number_of_blue+number_of_red
prob_of_black= number_of_black/total_number_of_balls
print(prob_of_black)
# Out:
# 0.5

# %%
number_of_red=2
number_of_blue=5
number_of_black=7
total_number_of_balls=number_of_black+number_of_blue+number_of_red
prob_of_black= number_of_black/total_number_of_balls
print("Probability of black is ",prob_of_black)
# Out:
# Probability of black is  0.5

# %% [markdown]
# ## String datatype
# A string datatype is a datatype that hold text or characters

# %%
first_name= "Boma"
last_name='George'
other_name="""Smith"""
state='''Rivers'''

# %%
print(first_name)
# Out:
# Boma

# %%
print(last_name)
# Out:
# George

# %%
print(other_name)
# Out:
# Smith

# %%
len(first_name)
# Out:
# 4

# %%
len(last_name)
# Out:
# 6

# %%
len(other_name)
# Out:
# 5

# %%
len(state)
# Out:
# 6

# %%
full_name= last_name+first_name

# %%
full_name
# Out:
# 'GeorgeBoma'

# %%
full_name =last_name+" "+first_name

# %%
full_name
# Out:
# 'George Boma'

# %%
full_name =last_name+" "+other_name+" "+first_name

# %%
full_name
# Out:
# 'George Smith Boma'

# %%
full_name =last_name+", "+other_name+" "+first_name

# %%
full_name
# Out:
# 'George, Smith Boma'

# %% [markdown]
# # string interpolation

# %%
full_name ="last_name other_name first_name"

# %%
full_name
# Out:
# 'last_name other_name first_name'

# %%
full_name =f"my name is {last_name} {other_name} {first_name}"

# %%
full_name
# Out:
# 'my name is George Smith Boma'

# %%
name = input("Enter your name: ")
state = input("Enter your state:")
age = int(input("Enter your age: "))
sentence=f"{name} is {age} years old and is from {state} state"
print(sentence)
# Out:
# Enter your name: George, Boma Smith bla bla bla
# Enter your state:Rivers
# Enter your age: 20
# George, Boma Smith bla bla bla is 20 years old and is from Rivers state

# %% [markdown]
# ## String Indexing and slicing

# %%
last_name
# Out:
# 'George'

# %%
last_name[0]
# Out:
# 'G'

# %%
last_name[1]
# Out:
# 'e'

# %%
first_name
# Out:
# 'Boma'

# %%
first_name[3]
# Out:
# 'a'

# %%
first_name
# Out:
# 'Boma'

# %%
last_name
# Out:
# 'George'

# %%
len(last_name)
# Out:
# 6

# %%
last_name[5]
# Out:
# 'e'

# %%
"Metamorphosis"[12]
# Out:
# 's'

# %%
name = input("Enter a name:")
length= len(name)
print(f"The last character of your name is {name[length-1]}")
# Out:
# Enter a name:Esther
# The last character of your name is r
