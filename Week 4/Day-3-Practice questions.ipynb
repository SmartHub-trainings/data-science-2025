# %%
from collections import Counter 

my_list = [3,1,2,3,4,3,2,2,2]
counter = Counter(my_list)
print(counter)

# most_common_element, count = counter.most_common(1)[0]
# print(f"the most common element is {most_common_element} (appears {count}times)")
# Out:
# Counter({2: 4, 3: 3, 1: 1, 4: 1})

# %%
x=4
x=x+5
print(x)
# Out:
# 9

# %%
c=4
c +=5
print(c)
# Out:
# 9

# %%
f=2
f =f*10 # f *=10
f-=6

# %%
def my_sum(numbers):
    total = 0
    for number in numbers:
        total +=number
    print(total)

# %%
my_sum([1,4,5])
# Out:
# 10

# %%
result =my_sum([1,4,5])
# Out:
# 10

# %%
print(result)
# Out:
# None

# %%
def my_sum(numbers):
    total = 0
    for number in numbers:
        total +=number
    print(total)
    return None

# %%
def my_sum(numbers):
    total = 0
    for number in numbers:
        total +=number
    return total

# %%
my_sum([3,4,2])
# Out:
# 9

# %%
result=my_sum([3,4,2])

# %%
result*2
# Out:
# 18

# %%
result/4
# Out:
# 2.25

# %%
def average(numbers):
    total = my_sum(numbers)
    avg= total/len(numbers)
    return avg

# %%
average([1,3,5])
# Out:
# 3.0

# %%
def average(numbers):
    avg= my_sum(numbers)/len(numbers)
    return avg

# %%
def average(numbers):
    return my_sum(numbers)/len(numbers)

# %%
def average3(numbers):return my_sum(numbers)/len(numbers)

# %%
average3([4,5,3])
# Out:
# 4.0

# %%
## main program
list_of_numbers =float(input("Enter numbers, separated by comma: "))
print(list_of_numbers)
print(type(list_of_numbers))
# Out:
# Enter numbers, separated by comma: 2,4,6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_40542/657565232.py in <module>
#       1 ## main program
# ----> 2 list_of_numbers =float(input("Enter numbers, separated by comma: "))
#       3 print(list_of_numbers)
#       4 print(type(list_of_numbers))
#
# ValueError: could not convert string to float: '2,4,6'

# %%
## main program
list_of_numbers =input("Enter numbers, separated by comma: ")
print(list_of_numbers)

print(type(list_of_numbers))
# Out:
# Enter numbers, separated by comma: 2,5,6,3,5
# 2,5,6,3,5
# <class 'str'>

# %%
## main program
list_of_numbers =input("Enter numbers, separated by comma: ")
print(list_of_numbers)
print(set(list_of_numbers))
print(type(list_of_numbers))
# Out:
# Enter numbers, separated by comma: 1,4,6
# 1,4,6
# {',', '4', '6', '1'}
# <class 'str'>

# %%
list_of_numbers =input("Enter numbers, separated by comma: ")
print(list_of_numbers)
print(list(list_of_numbers))
print(type(list_of_numbers))
# Out:
# Enter numbers, separated by comma: 5,7,5,7,3
# 5,7,5,7,3
# ['5', ',', '7', ',', '5', ',', '7', ',', '3']
# <class 'str'>

# %%
list_of_numbers =input("Enter numbers, separated by comma: ")
print(list_of_numbers)
print(list_of_numbers.split(","))
print(type(list_of_numbers))
# Out:
# Enter numbers, separated by comma: 1,3,6
# 1,3,6
# ['1', '3', '6']
# <class 'str'>

# %%
list_of_numbers =input("Enter numbers, separated by comma: ")
print(list_of_numbers)
list_splitted=list_of_numbers.split(",")
numbers =[]
for number in list_splitted:
    numbers.append(float(number))
print(numbers)
print(type(list_of_numbers))
# Out:
# Enter numbers, separated by comma: 2,5,6,7,1,2,10,8
# 2,5,6,7,1,2,10,8
# [2.0, 5.0, 6.0, 7.0, 1.0, 2.0, 10.0, 8.0]
# <class 'str'>

# %%
list_of_numbers =input("Enter numbers, separated by comma: ")
print(list_of_numbers)
list_splitted=list_of_numbers.split(",")
numbers =[]
for number in list_splitted:
    numbers.append(float(number))
menu ="""What operation do you want to perform?
1. Summation
2. Average
3. Mode
4. Median"""
print(menu)
# Out:
# Enter numbers, separated by comma: 1,3,4,6
# 1,3,4,6
# What operation do you want to perform?
# 1. Summation
# 2. Average
# 3. Mode
# 4. Median

# %%
list_of_numbers =input("Enter numbers, separated by comma: ")
print(list_of_numbers)
list_splitted=list_of_numbers.split(",")
numbers =[]
for number in list_splitted:
    numbers.append(float(number))
menu ="""What operation do you want to perform?
1. Summation
2. Average
3. Mode
4. Median\n"""
input(menu)
# Out:
# Enter numbers, separated by comma: 67,8,7,4
# 67,8,7,4
# What operation do you want to perform?
# 1. Summation
# 2. Average
# 3. Mode
# 4. Median
# 7
# '7'

# %%
list_of_numbers =input("Enter numbers, separated by comma: ")
print(list_of_numbers)
list_splitted=list_of_numbers.split(",")
numbers =[]
for number in list_splitted:
    numbers.append(float(number))
menu ="""What operation do you want to perform?
1. Summation
2. Average
3. Mode
4. Median\n"""
response=input(menu)
if response not in "1234":
    print("Invalid option")
elif response==1:
    result=my_sum(numbers)
    print(f"The sum is {result}")
elif response==2:
    result=average(numbers)
    print(f"The average is {result}")
# Out:
# Enter numbers, separated by comma: 1,6,4
# 1,6,4
# What operation do you want to perform?
# 1. Summation
# 2. Average
# 3. Mode
# 4. Median
# 1

# %%
list_of_numbers =input("Enter numbers, separated by comma: ")
print(list_of_numbers)
list_splitted=list_of_numbers.split(",")
numbers =[]
for number in list_splitted:
    numbers.append(float(number))
menu ="""What operation do you want to perform?
1. Summation
2. Average
3. Mode
4. Median\n"""
response=input(menu)
if response not in "1234":
    print("Invalid option")
elif response=="1":
    result=my_sum(numbers)
    print(f"The sum is {result}")
elif response=="2":
    result=average(numbers)
    print(f"The average is {result}")
# Out:
# Enter numbers, separated by comma: 6,7,4
# 6,7,4
# What operation do you want to perform?
# 1. Summation
# 2. Average
# 3. Mode
# 4. Median
# 2
# The average is 5.666666666666667

# %%
list_of_numbers =input("Enter numbers, separated by comma: ")
print(list_of_numbers)
list_splitted=list_of_numbers.split(",")
numbers =[]
for number in list_splitted:
    numbers.append(float(number))
menu ="""What operation do you want to perform?
1. Summation
2. Average
3. Mode
4. Median\n"""
response=input(menu)
if response not in "1234":
    print("Invalid option")
elif response=="1":
    result=my_sum(numbers)
    print(f"The sum is {result}")
elif response=="2":
    result=average(numbers)
    print(f"The average is {result}")
continuation_response = input("Do you wish to perform another operation on this set?(y/n)").lower()
if continuation_response in ("y","nah","no","nope"):
    pass
else:
    pass

# %%
list_of_numbers =input("Enter numbers, separated by comma: ")
print(list_of_numbers)
list_splitted=list_of_numbers.split(",")
numbers =[]
for number in list_splitted:
    numbers.append(float(number))
menu ="""What operation do you want to perform?
1. Summation
2. Average
3. Mode
4. Median\n"""
while True:
    response=input(menu)
    if response not in "1234":
        print("Invalid option")
    elif response=="1":
        result=my_sum(numbers)
        print(f"The sum is {result}")
    elif response=="2":
        result=average(numbers)
        print(f"The average is {result}")
    continuation_response = input("Do you wish to perform another operation on this set?(y/n)").lower()
    if continuation_response in ("n","nah","no","nope"):
        break
# Out:
# Enter numbers, separated by comma: 4,6,3
# 4,6,3
# What operation do you want to perform?
# 1. Summation
# 2. Average
# 3. Mode
# 4. Median
# 1
# The sum is 13.0
# Do you wish to perform another operation on this set?(y/n)y
# What operation do you want to perform?
# 1. Summation
# 2. Average
# 3. Mode
# 4. Median
# 2
# The average is 4.333333333333333
# Do you wish to perform another operation on this set?(y/n)yes
# What operation do you want to perform?
# 1. Summation
# 2. Average
# 3. Mode
# 4. Median
# 1
# The sum is 13.0
# Do you wish to perform another operation on this set?(y/n)nah

# %% [markdown]
# ## Median

# %%
def median(numbers):
    length =len(numbers)
    if length%2==0:
        pass
    else:
        pos= length//2
        return numbers[pos]

# %%
median([3,5,7,10,29,79,10])
# Out:
# 10

# %%
def median(numbers):
    length =len(numbers)
    numbers.sort()
    if length%2==0:
        pass
    else:
        pos= length//2
        return numbers[pos]

# %%
median([2,10,20,-1,5])
# Out:
# 5

# %%
def median(numbers):
    length =len(numbers)
    numbers.sort()
    if length%2==0:
        target_pos=length//2
        return (numbers[target_pos-1]+numbers[target_pos])/2
    else:
        pos= length//2
        return numbers[pos]

# %%
median([25,2,10,30])
# Out:
# 17.5

# %%
def median(numbers):
    length =len(numbers)
    my_numbers =list(numbers)
    my_numbers.sort()
    if length%2==0:
        target_pos=length//2
        return (my_numbers[target_pos-1]+my_numbers[target_pos])/2
    else:
        pos= length//2
        return my_numbers[pos]

# %%
median([30,10,90,30])
# Out:
# 30.0
