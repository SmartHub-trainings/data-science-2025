# %% [markdown]
# 17. Write a program that checks if a phone number is in the format "XXX-XXX-XXXX" where X is a digit.

# %%
## Esther/Chatgpt
# Get input from the user
phone_number = input("Enter a phone number (format: xxx-xxx-xxxx): ")

# Check the length first
if len(phone_number) == 12:
    # Check if dashes are in the correct positions
    if phone_number[3] == '-' and phone_number[7] == '-':
        # Check if all other characters are digits
        part1 = phone_number[0:3]
        part2 = phone_number[4:7]
        part3 = phone_number[8:12]

        if part1.isdigit() and part2.isdigit() and part3.isdigit():
            print("The phone number format is valid.")
        else:
            print("The phone number contains invalid characters.")
    else:
        print("The dashes are not in the correct positions.")
else:
    print("The phone number must be 12 characters long.")

# %%
phone_number = input("Enter a phone number")
print(phone_number.split("-"))

# %%
"This is me".split(" ")
# Out:
# ['This', 'is', 'me']

# %%
"This is me".split("i")
# Out:
# ['Th', 's ', 's me']

# %%
phone_number = input("Enter a phone number")
print(phone_number.split("-"))
# Out:
# Enter a phone number536664-578bnd-567363
# ['536664', '578bnd', '567363']

# %%
phone_number = input("Enter a phone number")
phone_splited=phone_number.split("-")
if len(phone_splited)==3:
    pass
else:
    print("Invalid phone number")
# Out:
# Enter a phone number765-455-3455

# %%
phone_number = input("Enter a phone number")
phone_splited=phone_number.split("-")
if len(phone_splited)==3:
    pass
else:
    print("Invalid phone number")
# Out:
# Enter a phone number674-556-5654-555
# Invalid phone number

# %%
phone_number = input("Enter a phone number")
phone_splited=phone_number.split("-")
if (len(phone_splited)==3 
    and len(phone_splited[0])==3 
    and len(phone_splited[1])==3 
    and len(phone_splited[2])==4
    and phone_splited[0].isdigit()
    and phone_splited[1].isdigit()
    and phone_splited[2].isdigit()
   ):
    print("Phone number is in the right format")
else:
    print("Invalid phone number")
# Out:
# Enter a phone number1234-566-4567
# Invalid phone number

# %%
"3454656".isdigit()
# Out:
# True

# %% [markdown]
# ## User defined functions

# %%
def add_2(x,y):#x and y are parameters, add_2(x,y) is the function signature
    #add_2 is the function name
    z = x+y
    print(z)

# %%
add_2(3,6)
# Out:
# 9

# %%
add_2(-23,6)
# Out:
# -17

# %%
add_2(4,6,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_91127/730114201.py in <module>
# ----> 1 add_2(4,6,7)
#
# TypeError: add_2() takes 2 positional arguments but 3 were given

# %%
import math as m
def sin(angle):
    result=m.sin(angle*m.pi/180)
    print(round(result,2))

# %%
sin(30)
# Out:
# 0.5

# %%
sin(60)
# Out:
# 0.87

# %%
sin(90)
# Out:
# 1.0

# %%
def send_message(name,message):
    result = f"{name} said {message}"
    print(result)

# %%
send_message("ChemChris","Give us more questions")
# Out:
# ChemChris said Give us more questions

# %%
def send_message(name,message):
    result = f'{name} said "{message}"'
    print(result)

# %%
send_message("ChemChris","Give us more questions")
# Out:
# ChemChris said "Give us more questions"
